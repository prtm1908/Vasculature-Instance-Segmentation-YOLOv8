# %%
from ultralytics import YOLO 
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('dataset/images/train/ed6a92a9410c.tif')
h,w,_=img.shape

# %%
model=YOLO('best.pt')
history=model(img)[0]
image=history.plot()
plt.imshow(image)
plt.show()
# Out:
# 0: 512x512 7 blood_vessels, 1 unsure, 83.4ms
# Speed: 1.0ms preprocess, 83.4ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 512)
